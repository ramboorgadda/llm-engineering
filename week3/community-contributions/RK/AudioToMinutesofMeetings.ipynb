# %% [markdown]
# # Meeting Minutes Generator (STT with LLMs)
# ---
#
# - 🌍 Task: Generate structured meeting minutes from audio recordings using Speech-to-Text (STT) and Large Language Models
# - 🧠 Models:
#     - AUDIO_MODEL: whisper1
#     - LLM_MODEL: meta-llama/Meta-Llama-3.1-8B-Instruct
# - 🚀 Tools: Python, Gradio UI, OpenAI / HuggingFace APIs
# - 📤 Output: Structured meeting minutes in Markdown format with real-time streaming
# - 🧑‍💻 Skill Level: Intermediate
#
# 🎯 How It Works
# - 1️⃣ Upload a .mp3 meeting recording
# - 2️⃣ Submit the audio to generate meeting minutes in text format
#
# You can download some meetings from this link to test the code:
# [https://www.rmofspringfield.ca/p/meeting-audio-files](https://www.rmofspringfield.ca/p/meeting-audio-files)
#
#
# 🛠️ Requirements
# - ⚙️ Hardware: ✅ GPU required (model download); Google Colab recommended (T4)
# - 🔑 OpenAI API Key (used for whisper1 transcription)
# - 🔑 Hugging Face Token (for the LLM model)
#
# ⚙️ Customizable by user
# - 🤖 Selected model: AUDIO_MODEL / LLM_MODEL
# - 📜 system_prompt: Controls model behavior (concise, accurate, structured output)
# - 💬 user_prompt
#
# ---
# 📢 Find more LLM notebooks on my [GitHub repository](https://github.com/ramboorgadda/llm-engineering)

# %%
# %pip install -q requests torch bitsandbytes transformers sentencepiece accelerate openai httpx==0.28.1 gradio

# %pip install -U bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.49.0)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.9.0+cu126)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)

# %%
# !pip install -U bitsandbytes
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.49.0)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.9.0+cu126)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)

# %%
import torch
import threading
from openai import OpenAI
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline,BitsAndBytesConfig,TextIteratorStreamer
from huggingface_hub import login
from google.colab import userdata
import requests
import gradio as gr

# %%
AUDIO_MODEL="whisper-1"
LLM_MODEL="meta-llama/Meta-Llama-3.1-8B-Instruct"

# %%
hf_token=userdata.get("HF_TOKEN")
openai=OpenAI(api_key=userdata.get("OPENAI_API_KEY"))
login(hf_token,add_to_git_credential=True)

# %%
import torch
import threading
from openai import OpenAI
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline,BitsAndBytesConfig,TextIteratorStreamer
from huggingface_hub import login
from google.colab import userdata
import requests
import gradio as gr

class MeetingAssistant:

  def __init__(self,model_name=LLM_MODEL,audio_model=AUDIO_MODEL):

      quant_config=BitsAndBytesConfig(load_in_4bit=True, # Fixed: Load_in_4bit -> load_in_4bit
                                  bnb_4bit_use_double_quant=True,
                                  bnb_4bit_quant_type="nf4",
                                  bnb_4bit_compute_dtype=torch.bfloat16)

      self.tokenizer=AutoTokenizer.from_pretrained(model_name)
      self.model=AutoModelForCausalLM.from_pretrained(model_name,
                                                      quantization_config=quant_config,
                                                      device_map="auto")


  def transcribe_audio(self,audio_path,progress=None):
    """Transcribe the uploaded audi file using OpenI whisper"""
    if progress is None:
        progress = lambda x, desc: None # Dummy progress function
    print(f"[DEBUG] transcribe_audio called with path: {audio_path}")

    progress(0.3,"Transcribing Audio")
    try:
      with open(audio_path,"rb") as audio_file:
         transcript=openai.audio.transcriptions.create(model=AUDIO_MODEL,
                                            file=audio_file,
                                            response_format="text")
         print(f"[DEBUG] Transcription successful. Transcript length: {len(transcript) if transcript else 0}")
         print(f"[DEBUG] Transcript preview: {transcript[:200]}...") # Print first 200 chars
         return transcript
    except Exception as e:
      print(f"[ERROR] Error during transcription: {str(e)}")
      return f"Error during transcription: {str(e)}"

  def generate_minutes(self,transcription,progress=None):
    """Generate meeting minutes using LLM"""
    if progress is None:
        progress = lambda x, desc: None # Dummy progress function
    print(f"[DEBUG] generate_minutes called. Transcription length: {len(transcription) if transcription else 0}")
    progress(0.6,desc="Generating Minutes")
    system_message="You are an assistant that produces minutes of meetings from transcripts, with summary, key discussion points, takeaways and action items with owners, in markdown."
    user_prompt=f"Below is an extract transcript of a meeting. Please write minutes in markdown, including a summary with attendees, location and date; discussion points; takeaways; and action items with owners.\n{transcription}"

    messages=[{"role":"system","content":system_message},
              {"role":"user","content":user_prompt}]
    print(f"[DEBUG] Messages sent to LLM: {messages}")

    inputs = self.tokenizer.apply_chat_template(messages,return_tensors="pt").to("cuda")
    streamer = TextIteratorStreamer(self.tokenizer)
    thread = threading.Thread(target=self.model.generate,kwargs={
                    "input_ids": inputs,
                    "max_new_tokens": 2000,
                    "streamer": streamer
    })
    thread.start()

    started = False
    full_response = ""
    for new_text in streamer:
      print(f"[DEBUG] Streamer received text chunk: {new_text}")
      if not started:
        if "<|start_header_id|>assistant<|end_header_id|>" in new_text:
          started = True
          new_text = new_text.split("<|start_header_id|>assistant<|end_header_id|>")[-1].strip()
      if started:
        if "<|eot_id|>" in new_text:
          new_text = new_text.replace("<|eot_id|>","")

        if new_text.strip():
          full_response += new_text
          yield full_response # Yield the accumulated text for Gradio streaming


  def process_meeting(self,audio_file_path,progress=None):
    """Handles the complete file of transcribing the file and generating the minutes."""
    if progress is None:
        progress = lambda x, desc: None # Dummy progress function
    print(f"[DEBUG] process_meeting called with audio_file_path: {audio_file_path}")
    progress(0.1,desc="Processing the audio file")

    if audio_file_path is None:
      print("[DEBUG] No audio file uploaded.")
      return "Please upload an audio file."

    try:
      # audio_file_path is now expected to be a string (the path)
      if audio_file_path.split(".")[-1] != "mp3":
        print(f"[DEBUG] Invalid file type: {audio_file_path.split('.')[-1]}")
        return "Please upload an mp3 file"

      transcription = self.transcribe_audio(audio_file_path,progress) # Pass the string path
      if "Error during transcription" in transcription:
          print(f"[ERROR] Transcription error encountered: {transcription}")
          yield transcription # Yield error message
          return
      print(f"[DEBUG] Transcription received in process_meeting. Length: {len(transcription) if transcription else 0}")

      minutes_generator = self.generate_minutes(transcription,progress)
      accumulated_text = ""
      try:
        for chunk in minutes_generator:
          accumulated_text = chunk # The generator now yields accumulated text
          print(f"[DEBUG] Yielding accumulated chunk to GradioInterface. Current length: {len(accumulated_text)}")
          yield accumulated_text
      except Exception as llm_e:
          print(f"[ERROR] Error during LLM generation streaming: {str(llm_e)}")
          yield f"Error during LLM generation streaming: {str(llm_e)}"

    except Exception as e:
      print(f"[ERROR] Error during overall processing: {str(e)}")
      return f"Error during overall processing: {str(e)}"

# %%
#Gradio Interface

class GradioInterface():
  def __init__(self):
    """ Initialize Gradio Interface to process audio files """

    self.assistant=MeetingAssistant()
    self.iface=gr.Interface(fn=self.process_audio,
                            inputs=gr.Audio(type="filepath", label="Upload MP3 File", format="mp3"),
                            outputs=gr.Markdown(label="Meeting Minutes",min_height=60),
                            title="AI Meeting Assistant",
                            description="Upload an audio file to transcribe and generate meeting minutes.",
                            flagging_mode="never")



  def process_audio(self,audio_file,progress=None):
    """Handle the userInput from Gradio Process the file and return the minutes of meeting"""
    print(f"[DEBUG] process_audio function called by Gradio.")
    if progress is None:
        progress = gr.Progress() # Instantiate gr.Progress() if not provided by Gradio
    minutes_generator = self.assistant.process_meeting(audio_file,progress)
    print(f"[DEBUG] After the process_meeting call, starting to iterate minutes_generator")
    try:
        for chunk in minutes_generator:
          print(f"[DEBUG] GradioInterface yielding chunk to UI. Length: {len(chunk)}")
          yield chunk
    except Exception as e:
        print(f"[ERROR] Error in process_audio yielding: {str(e)}")
        yield f"Error in Gradio interface: {str(e)}"

  def launch(self):
        """Launches the Gradio interface."""
        self.iface.launch(debug=True)

# %%
if __name__ == "__main__":
    app = GradioInterface()
    app.launch()
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://f7cc830a29bd4e5c68.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f7cc830a29bd4e5c68.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/uvicorn/protocols/http/h11_impl.py", line 403, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/applications.py", line 1139, in __call__
#     await super().__call__(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/middleware/errors.py", line 186, in __call__
#     raise exc
#   File "/usr/local/lib/python3.12/dist-packages/starlette/middleware/errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "/usr/local/lib/python3.12/dist-packages/gradio/brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 882, in __call__
#     await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/middleware/exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "/usr/local/lib/python3.12/dist-packages/starlette/_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/middleware/asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/routing.py", line 119, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "/usr/local/lib/python3.12/dist-packages/starlette/_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/routing.py", line 105, in app
#     response = await f(request)
#                ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/routing.py", line 385, in app
#     raw_response = await run_endpoint_function(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/routing.py", line 284, in run_endpoint_function
#     return await dependant.call(**values)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/routes.py", line 1671, in get_upload_progress
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 528, in is_tracked
#     return await self._signals[upload_id].wait()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/locks.py", line 209, in wait
#     fut = self._get_loop().create_future()
#           ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/mixins.py", line 20, in _get_loop
#     raise RuntimeError(f'{self!r} is bound to a different event loop')
# RuntimeError: <asyncio.locks.Event object at 0x79adccd0f500 [unset]> is bound to a different event loop
# [DEBUG] process_audio function called by Gradio.
# [DEBUG] After the process_meeting call, starting to iterate minutes_generator
# [DEBUG] process_meeting called with audio_file_path: /tmp/gradio/12785fa57f15a30a4344511967a197a0c9e00cd07df575d151d0c092824effc4/denver_extract.mp3
# [DEBUG] transcribe_audio called with path: /tmp/gradio/12785fa57f15a30a4344511967a197a0c9e00cd07df575d151d0c092824effc4/denver_extract.mp3
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [DEBUG] Transcription successful. Transcript length: 12515
# [DEBUG] Transcript preview: and kind of the confluence of this whole idea of the confluence week, the merging of two rivers and as we've kind of seen recently in politics and in the world, there's a lot of situations where water...
# [DEBUG] Transcription received in process_meeting. Length: 12515
# [DEBUG] generate_minutes called. Transcription length: 12515
# [DEBUG] Messages sent to LLM: [{'role': 'system', 'content': 'You are an assistant that produces minutes of meetings from transcripts, with summary, key discussion points, takeaways and action items with owners, in markdown.'}, {'role': 'user', 'content': "Below is an extract transcript of a meeting. Please write minutes in markdown, including a summary with attendees, location and date; discussion points; takeaways; and action items with owners.\nand kind of the confluence of this whole idea of the confluence week, the merging of two rivers and as we've kind of seen recently in politics and in the world, there's a lot of situations where water is very important right now and it's a very big issue. So that is the reason that the back of the logo is considered water. So let me see the creation of the logo here. So that basically kind of sums up the reason behind the logo and all the meanings behind the symbolism and you'll hear a little bit more about our confluence week is basically highlighting all of these indigenous events and things that are happening around Denver so that we can kind of bring more people together and kind of share this whole idea of Indigenous People's Day. So thank you. Thank you so much and thanks for your leadership. All right. Welcome to the Denver City Council meeting of Monday, October 9th. Please rise with the Pledge of Allegiance by Councilman Lopez. I pledge allegiance to the flag of the United States of America, and to the republic for which it stands, one nation, under God, indivisible, with liberty and justice for all. All right. Thank you, Councilman Lopez. Madam Secretary, roll call. Clerk. Here. Espinosa. Here. Flynn. Here. Gilmour. Here. Here. Cashman. Here. Kenneche. Here. Lopez. Here. New. Here. Ortega. Here. Sussman. Here. Mr. President. Here. 11 present. 11 members present. We do have a quorum. Approval of the minutes. Seeing none. Minutes of October 2nd stand approved. Council announcements. Are there any announcements by members of Council? Councilman Clark. Thank you, Mr. President. I just wanted to invite everyone down to the first ever Halloween Parade on Broadway in Lucky District 7. It will happen on Saturday, October 21st at 6 o'clock p.m. It will move along Broadway from 3rd to Alameda. It's going to be a fun, family-friendly event. Everyone's invited to come down, wear a costume. There will be candy for the kids and there are tiki zombies and 29 hearses and all kinds of fun and funky stuff on the fun and funky part of Broadway. So please join us October 21st at 6 o'clock for the Broadway Halloween Parade. Thank you, Mr. President. All right. Thank you, Councilman Clark. I will be there. All right. Presentations. Madam Secretary, do we have any presentations? None, Mr. President. Communications. Do we have any communications? None, Mr. President. We do have one proclamation this evening. Proclamation 1127, an observance of the annual Indigenous Peoples Day in the City and County of Denver. Councilman Lopez, will you please read it? Thank you, Mr. President, with pride. Proclamation number 17, well, let me just say this differently. Proclamation number 1127, series of 2017, an observance of the second annual Indigenous Peoples Day in the City and County of Denver. Whereas the Council of the City and County of Denver recognizes that the Indigenous Peoples have lived and flourished on the lands known as the Americas since time immemorial and that Denver and the surrounding communities are built upon the ancestral homelands of numerous Indigenous tribes, which include the Southern Ute, the Ute Mountain, Ute tribes of Colorado. And whereas the tribal homelands and seasonal encampments of the Arapaho and Cheyenne people along the banks of the Cherry Creek and South Platte River confluence gave bearing to the future settlements that would become the birthplace of the Mile High City. And whereas Colorado encompasses the ancestral homelands of 48 tribes and the City and County of Denve ...
# [DEBUG] Streamer received text chunk: <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# You are an assistant that produces minutes of meetings from transcripts, with summary, key discussion points, takeaways and action items with owners, in markdown.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Below is an extract transcript of a meeting. Please write minutes in markdown, including a summary with attendees, location and date; discussion points; takeaways; and action items with owners.
# and kind of the confluence of this whole idea of the confluence week, the merging of two rivers and as we've kind of seen recently in politics and in the world, there's a lot of situations where water is very important right now and it's a very big issue. So that is the reason that the back of the logo is considered water. So let me see the creation of the logo here. So that basically kind of sums up the reason behind the logo and all the meanings behind the symbolism and you'll hear a little bit more about our confluence week is basically highlighting all of these indigenous events and things that are happening around Denver so that we can kind of bring more people together and kind of share this whole idea of Indigenous People's Day. So thank you. Thank you so much and thanks for your leadership. All right. Welcome to the Denver City Council meeting of Monday, October 9th. Please rise with the Pledge of Allegiance by Councilman Lopez. I pledge allegiance to the flag of the United States of America, and to the republic for which it stands, one nation, under God, indivisible, with liberty and justice for all. All right. Thank you, Councilman Lopez. Madam Secretary, roll call. Clerk. Here. Espinosa. Here. Flynn. Here. Gilmour. Here. Here. Cashman. Here. Kenneche. Here. Lopez. Here. New. Here. Ortega. Here. Sussman. Here. Mr. President. Here. 11 present. 11 members present. We do have a quorum. Approval of the minutes. Seeing none. Minutes of October 2nd stand approved. Council announcements. Are there any announcements by members of Council? Councilman Clark. Thank you, Mr. President. I just wanted to invite everyone down to the first ever Halloween Parade on Broadway in Lucky District 7. It will happen on Saturday, October 21st at 6 o'clock p.m. It will move along Broadway from 3rd to Alameda. It's going to be a fun, family-friendly event. Everyone's invited to come down, wear a costume. There will be candy for the kids and there are tiki zombies and 29 hearses and all kinds of fun and funky stuff on the fun and funky part of Broadway. So please join us October 21st at 6 o'clock for the Broadway Halloween Parade. Thank you, Mr. President. All right. Thank you, Councilman Clark. I will be there. All right. Presentations. Madam Secretary, do we have any presentations? None, Mr. President. Communications. Do we have any communications? None, Mr. President. We do have one proclamation this evening. Proclamation 1127, an observance of the annual Indigenous Peoples Day in the City and County of Denver. Councilman Lopez, will you please read it? Thank you, Mr. President, with pride. Proclamation number 17, well, let me just say this differently. Proclamation number 1127, series of 2017, an observance of the second annual Indigenous Peoples Day in the City and County of Denver. Whereas the Council of the City and County of Denver recognizes that the Indigenous Peoples have lived and flourished on the lands known as the Americas since time immemorial and that Denver and the surrounding communities are built upon the ancestral homelands of numerous Indigenous tribes, which include the Southern Ute, the Ute Mountain, Ute tribes of Colorado. And whereas the tribal homelands and seasonal encampments of the Arapaho and Cheyenne people along the banks of the Cherry Creek and South Platte River confluence gave bearing to the future settlements that would become the birthplace of the Mile High City. And whereas Colorado encompasses the ancestral homelands of 48 tribes and the City and County of Denver and surrounding communities are home to the descendants of approximately 100 tribal nations. And whereas on October 3, 2016, the City and County of Denver unanimously passed Council Bill 801, series of 2016, officially designating the second Monday of October of each year as Indigenous Peoples Day in Denver, Colorado. And whereas the Council of the City and County of Denver continues to recognize and value the vast contributions made to the commu ...
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: honestly.<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
#
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: **Minutes
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 10
# [DEBUG] GradioInterface yielding chunk to UI. Length: 10
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 13
# [DEBUG] GradioInterface yielding chunk to UI. Length: 13
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 17
# [DEBUG] GradioInterface yielding chunk to UI. Length: 17
# [DEBUG] Streamer received text chunk: Denver
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 24
# [DEBUG] GradioInterface yielding chunk to UI. Length: 24
# [DEBUG] Streamer received text chunk: City
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 29
# [DEBUG] GradioInterface yielding chunk to UI. Length: 29
# [DEBUG] Streamer received text chunk: Council
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 37
# [DEBUG] GradioInterface yielding chunk to UI. Length: 37
# [DEBUG] Streamer received text chunk: Meeting**
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 47
# [DEBUG] GradioInterface yielding chunk to UI. Length: 47
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: =============================================
#
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 94
# [DEBUG] GradioInterface yielding chunk to UI. Length: 94
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: **Date:**
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 104
# [DEBUG] GradioInterface yielding chunk to UI. Length: 104
# [DEBUG] Streamer received text chunk: October
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 112
# [DEBUG] GradioInterface yielding chunk to UI. Length: 112
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: 9,
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 115
# [DEBUG] GradioInterface yielding chunk to UI. Length: 115
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: 2017
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 120
# [DEBUG] GradioInterface yielding chunk to UI. Length: 120
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: **Location:**
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 134
# [DEBUG] GradioInterface yielding chunk to UI. Length: 134
# [DEBUG] Streamer received text chunk: Denver
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 141
# [DEBUG] GradioInterface yielding chunk to UI. Length: 141
# [DEBUG] Streamer received text chunk: City
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 146
# [DEBUG] GradioInterface yielding chunk to UI. Length: 146
# [DEBUG] Streamer received text chunk: Council
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 154
# [DEBUG] GradioInterface yielding chunk to UI. Length: 154
# [DEBUG] Streamer received text chunk: Chambers
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 163
# [DEBUG] GradioInterface yielding chunk to UI. Length: 163
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: **Attendees:**
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 178
# [DEBUG] GradioInterface yielding chunk to UI. Length: 178
# [DEBUG] Streamer received text chunk: Council
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 186
# [DEBUG] GradioInterface yielding chunk to UI. Length: 186
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Members,
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 195
# [DEBUG] GradioInterface yielding chunk to UI. Length: 195
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Clerk,
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 202
# [DEBUG] GradioInterface yielding chunk to UI. Length: 202
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 206
# [DEBUG] GradioInterface yielding chunk to UI. Length: 206
# [DEBUG] Streamer received text chunk: other
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 212
# [DEBUG] GradioInterface yielding chunk to UI. Length: 212
# [DEBUG] Streamer received text chunk: officials
#
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 223
# [DEBUG] GradioInterface yielding chunk to UI. Length: 223
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: **Summary:**
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 236
# [DEBUG] GradioInterface yielding chunk to UI. Length: 236
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: The
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 240
# [DEBUG] GradioInterface yielding chunk to UI. Length: 240
# [DEBUG] Streamer received text chunk: Denver
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 247
# [DEBUG] GradioInterface yielding chunk to UI. Length: 247
# [DEBUG] Streamer received text chunk: City
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 252
# [DEBUG] GradioInterface yielding chunk to UI. Length: 252
# [DEBUG] Streamer received text chunk: Council
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 260
# [DEBUG] GradioInterface yielding chunk to UI. Length: 260
# [DEBUG] Streamer received text chunk: met
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 264
# [DEBUG] GradioInterface yielding chunk to UI. Length: 264
# [DEBUG] Streamer received text chunk: to
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 267
# [DEBUG] GradioInterface yielding chunk to UI. Length: 267
# [DEBUG] Streamer received text chunk: discuss
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 275
# [DEBUG] GradioInterface yielding chunk to UI. Length: 275
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 279
# [DEBUG] GradioInterface yielding chunk to UI. Length: 279
# [DEBUG] Streamer received text chunk: approve
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 287
# [DEBUG] GradioInterface yielding chunk to UI. Length: 287
# [DEBUG] Streamer received text chunk: a
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 289
# [DEBUG] GradioInterface yielding chunk to UI. Length: 289
# [DEBUG] Streamer received text chunk: proclamation
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 302
# [DEBUG] GradioInterface yielding chunk to UI. Length: 302
# [DEBUG] Streamer received text chunk: for
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 306
# [DEBUG] GradioInterface yielding chunk to UI. Length: 306
# [DEBUG] Streamer received text chunk: Indigenous
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 317
# [DEBUG] GradioInterface yielding chunk to UI. Length: 317
# [DEBUG] Streamer received text chunk: Peoples
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 325
# [DEBUG] GradioInterface yielding chunk to UI. Length: 325
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Day.
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 330
# [DEBUG] GradioInterface yielding chunk to UI. Length: 330
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Councilman
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 341
# [DEBUG] GradioInterface yielding chunk to UI. Length: 341
# [DEBUG] Streamer received text chunk: Lopez
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 347
# [DEBUG] GradioInterface yielding chunk to UI. Length: 347
# [DEBUG] Streamer received text chunk: presented
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 357
# [DEBUG] GradioInterface yielding chunk to UI. Length: 357
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 361
# [DEBUG] GradioInterface yielding chunk to UI. Length: 361
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: proclamation,
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 375
# [DEBUG] GradioInterface yielding chunk to UI. Length: 375
# [DEBUG] Streamer received text chunk: highlighting
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 388
# [DEBUG] GradioInterface yielding chunk to UI. Length: 388
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 392
# [DEBUG] GradioInterface yielding chunk to UI. Length: 392
# [DEBUG] Streamer received text chunk: importance
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 403
# [DEBUG] GradioInterface yielding chunk to UI. Length: 403
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 406
# [DEBUG] GradioInterface yielding chunk to UI. Length: 406
# [DEBUG] Streamer received text chunk: recognizing
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 418
# [DEBUG] GradioInterface yielding chunk to UI. Length: 418
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 422
# [DEBUG] GradioInterface yielding chunk to UI. Length: 422
# [DEBUG] Streamer received text chunk: celebrating
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 434
# [DEBUG] GradioInterface yielding chunk to UI. Length: 434
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 438
# [DEBUG] GradioInterface yielding chunk to UI. Length: 438
# [DEBUG] Streamer received text chunk: contributions
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 452
# [DEBUG] GradioInterface yielding chunk to UI. Length: 452
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 455
# [DEBUG] GradioInterface yielding chunk to UI. Length: 455
# [DEBUG] Streamer received text chunk: Indigenous
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 466
# [DEBUG] GradioInterface yielding chunk to UI. Length: 466
# [DEBUG] Streamer received text chunk: people
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 473
# [DEBUG] GradioInterface yielding chunk to UI. Length: 473
# [DEBUG] Streamer received text chunk: to
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 476
# [DEBUG] GradioInterface yielding chunk to UI. Length: 476
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 480
# [DEBUG] GradioInterface yielding chunk to UI. Length: 480
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: city's
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 487
# [DEBUG] GradioInterface yielding chunk to UI. Length: 487
# [DEBUG] Streamer received text chunk: history
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 495
# [DEBUG] GradioInterface yielding chunk to UI. Length: 495
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 499
# [DEBUG] GradioInterface yielding chunk to UI. Length: 499
# [DEBUG] Streamer received text chunk: culture.
#
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 509
# [DEBUG] GradioInterface yielding chunk to UI. Length: 509
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: **Key
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 515
# [DEBUG] GradioInterface yielding chunk to UI. Length: 515
# [DEBUG] Streamer received text chunk: Discussion
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 526
# [DEBUG] GradioInterface yielding chunk to UI. Length: 526
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Points:**
#
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 537
# [DEBUG] GradioInterface yielding chunk to UI. Length: 537
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: *
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 539
# [DEBUG] GradioInterface yielding chunk to UI. Length: 539
# [DEBUG] Streamer received text chunk: The
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 543
# [DEBUG] GradioInterface yielding chunk to UI. Length: 543
# [DEBUG] Streamer received text chunk: proclamation
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 556
# [DEBUG] GradioInterface yielding chunk to UI. Length: 556
# [DEBUG] Streamer received text chunk: was
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 560
# [DEBUG] GradioInterface yielding chunk to UI. Length: 560
# [DEBUG] Streamer received text chunk: read
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 565
# [DEBUG] GradioInterface yielding chunk to UI. Length: 565
# [DEBUG] Streamer received text chunk: by
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 568
# [DEBUG] GradioInterface yielding chunk to UI. Length: 568
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Councilman
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 579
# [DEBUG] GradioInterface yielding chunk to UI. Length: 579
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Lopez,
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 586
# [DEBUG] GradioInterface yielding chunk to UI. Length: 586
# [DEBUG] Streamer received text chunk: emphasizing
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 598
# [DEBUG] GradioInterface yielding chunk to UI. Length: 598
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 602
# [DEBUG] GradioInterface yielding chunk to UI. Length: 602
# [DEBUG] Streamer received text chunk: significance
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 615
# [DEBUG] GradioInterface yielding chunk to UI. Length: 615
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 618
# [DEBUG] GradioInterface yielding chunk to UI. Length: 618
# [DEBUG] Streamer received text chunk: Indigenous
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 629
# [DEBUG] GradioInterface yielding chunk to UI. Length: 629
# [DEBUG] Streamer received text chunk: Peoples
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 637
# [DEBUG] GradioInterface yielding chunk to UI. Length: 637
# [DEBUG] Streamer received text chunk: Day
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 641
# [DEBUG] GradioInterface yielding chunk to UI. Length: 641
# [DEBUG] Streamer received text chunk: in
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 644
# [DEBUG] GradioInterface yielding chunk to UI. Length: 644
# [DEBUG] Streamer received text chunk: acknowledging
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 658
# [DEBUG] GradioInterface yielding chunk to UI. Length: 658
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 662
# [DEBUG] GradioInterface yielding chunk to UI. Length: 662
# [DEBUG] Streamer received text chunk: cultural
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 671
# [DEBUG] GradioInterface yielding chunk to UI. Length: 671
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 675
# [DEBUG] GradioInterface yielding chunk to UI. Length: 675
# [DEBUG] Streamer received text chunk: foundational
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 688
# [DEBUG] GradioInterface yielding chunk to UI. Length: 688
# [DEBUG] Streamer received text chunk: contributions
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 702
# [DEBUG] GradioInterface yielding chunk to UI. Length: 702
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 705
# [DEBUG] GradioInterface yielding chunk to UI. Length: 705
# [DEBUG] Streamer received text chunk: Indigenous
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 716
# [DEBUG] GradioInterface yielding chunk to UI. Length: 716
# [DEBUG] Streamer received text chunk: people
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 723
# [DEBUG] GradioInterface yielding chunk to UI. Length: 723
# [DEBUG] Streamer received text chunk: to
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 726
# [DEBUG] GradioInterface yielding chunk to UI. Length: 726
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 730
# [DEBUG] GradioInterface yielding chunk to UI. Length: 730
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: city's
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 737
# [DEBUG] GradioInterface yielding chunk to UI. Length: 737
# [DEBUG] Streamer received text chunk: history.
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 746
# [DEBUG] GradioInterface yielding chunk to UI. Length: 746
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: *
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 748
# [DEBUG] GradioInterface yielding chunk to UI. Length: 748
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Councilman
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 759
# [DEBUG] GradioInterface yielding chunk to UI. Length: 759
# [DEBUG] Streamer received text chunk: Lopez
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 765
# [DEBUG] GradioInterface yielding chunk to UI. Length: 765
# [DEBUG] Streamer received text chunk: discussed
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 775
# [DEBUG] GradioInterface yielding chunk to UI. Length: 775
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 779
# [DEBUG] GradioInterface yielding chunk to UI. Length: 779
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: confluence
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 790
# [DEBUG] GradioInterface yielding chunk to UI. Length: 790
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 793
# [DEBUG] GradioInterface yielding chunk to UI. Length: 793
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 797
# [DEBUG] GradioInterface yielding chunk to UI. Length: 797
# [DEBUG] Streamer received text chunk: two
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 801
# [DEBUG] GradioInterface yielding chunk to UI. Length: 801
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: rivers,
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 809
# [DEBUG] GradioInterface yielding chunk to UI. Length: 809
# [DEBUG] Streamer received text chunk: which
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 815
# [DEBUG] GradioInterface yielding chunk to UI. Length: 815
# [DEBUG] Streamer received text chunk: gave
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 820
# [DEBUG] GradioInterface yielding chunk to UI. Length: 820
# [DEBUG] Streamer received text chunk: bearing
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 828
# [DEBUG] GradioInterface yielding chunk to UI. Length: 828
# [DEBUG] Streamer received text chunk: to
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 831
# [DEBUG] GradioInterface yielding chunk to UI. Length: 831
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 835
# [DEBUG] GradioInterface yielding chunk to UI. Length: 835
# [DEBUG] Streamer received text chunk: future
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 842
# [DEBUG] GradioInterface yielding chunk to UI. Length: 842
# [DEBUG] Streamer received text chunk: settlements
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 854
# [DEBUG] GradioInterface yielding chunk to UI. Length: 854
# [DEBUG] Streamer received text chunk: that
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 859
# [DEBUG] GradioInterface yielding chunk to UI. Length: 859
# [DEBUG] Streamer received text chunk: became
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 866
# [DEBUG] GradioInterface yielding chunk to UI. Length: 866
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 870
# [DEBUG] GradioInterface yielding chunk to UI. Length: 870
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: birthplace
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 881
# [DEBUG] GradioInterface yielding chunk to UI. Length: 881
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 884
# [DEBUG] GradioInterface yielding chunk to UI. Length: 884
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 888
# [DEBUG] GradioInterface yielding chunk to UI. Length: 888
# [DEBUG] Streamer received text chunk: Mile
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 893
# [DEBUG] GradioInterface yielding chunk to UI. Length: 893
# [DEBUG] Streamer received text chunk: High
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 898
# [DEBUG] GradioInterface yielding chunk to UI. Length: 898
# [DEBUG] Streamer received text chunk: City.
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 904
# [DEBUG] GradioInterface yielding chunk to UI. Length: 904
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: *
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 906
# [DEBUG] GradioInterface yielding chunk to UI. Length: 906
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Councilwoman
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 919
# [DEBUG] GradioInterface yielding chunk to UI. Length: 919
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Ortega
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 926
# [DEBUG] GradioInterface yielding chunk to UI. Length: 926
# [DEBUG] Streamer received text chunk: shared
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 933
# [DEBUG] GradioInterface yielding chunk to UI. Length: 933
# [DEBUG] Streamer received text chunk: her
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 937
# [DEBUG] GradioInterface yielding chunk to UI. Length: 937
# [DEBUG] Streamer received text chunk: experience
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 948
# [DEBUG] GradioInterface yielding chunk to UI. Length: 948
# [DEBUG] Streamer received text chunk: with
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 953
# [DEBUG] GradioInterface yielding chunk to UI. Length: 953
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 957
# [DEBUG] GradioInterface yielding chunk to UI. Length: 957
# [DEBUG] Streamer received text chunk: Commission
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 968
# [DEBUG] GradioInterface yielding chunk to UI. Length: 968
# [DEBUG] Streamer received text chunk: on
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 971
# [DEBUG] GradioInterface yielding chunk to UI. Length: 971
# [DEBUG] Streamer received text chunk: Indian
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 978
# [DEBUG] GradioInterface yielding chunk to UI. Length: 978
# [DEBUG] Streamer received text chunk: Affairs
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 986
# [DEBUG] GradioInterface yielding chunk to UI. Length: 986
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 990
# [DEBUG] GradioInterface yielding chunk to UI. Length: 990
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 994
# [DEBUG] GradioInterface yielding chunk to UI. Length: 994
# [DEBUG] Streamer received text chunk: importance
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1005
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1005
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1008
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1008
# [DEBUG] Streamer received text chunk: preserving
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1019
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1019
# [DEBUG] Streamer received text chunk: Native
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1026
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1026
# [DEBUG] Streamer received text chunk: American
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1035
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1035
# [DEBUG] Streamer received text chunk: culture
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1043
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1043
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1047
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1047
# [DEBUG] Streamer received text chunk: language.
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1057
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1057
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: *
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1059
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1059
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Councilwoman
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1072
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1072
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Kinneach
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1081
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1081
# [DEBUG] Streamer received text chunk: highlighted
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1093
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1093
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1097
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1097
# [DEBUG] Streamer received text chunk: connection
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1108
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1108
# [DEBUG] Streamer received text chunk: between
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1116
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1116
# [DEBUG] Streamer received text chunk: cultural
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1125
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1125
# [DEBUG] Streamer received text chunk: preservation
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1138
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1138
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1142
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1142
# [DEBUG] Streamer received text chunk: environmental
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1156
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1156
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: protection,
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1168
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1168
# [DEBUG] Streamer received text chunk: emphasizing
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1180
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1180
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1184
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1184
# [DEBUG] Streamer received text chunk: importance
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1195
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1195
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1198
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1198
# [DEBUG] Streamer received text chunk: protecting
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1209
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1209
# [DEBUG] Streamer received text chunk: public
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1216
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1216
# [DEBUG] Streamer received text chunk: lands.
#
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1224
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1224
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: **Takeaways:**
#
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1240
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1240
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: *
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1242
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1242
# [DEBUG] Streamer received text chunk: The
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1246
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1246
# [DEBUG] Streamer received text chunk: city
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1251
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1251
# [DEBUG] Streamer received text chunk: recognizes
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1262
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1262
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1266
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1266
# [DEBUG] Streamer received text chunk: celebrates
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1277
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1277
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1281
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1281
# [DEBUG] Streamer received text chunk: contributions
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1295
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1295
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1298
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1298
# [DEBUG] Streamer received text chunk: Indigenous
# ...
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1683
# [DEBUG] Streamer received text chunk: to
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1686
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1686
# [DEBUG] Streamer received text chunk: Relevant
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1695
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1695
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Parties:**
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1706
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1706
# [DEBUG] Streamer received text chunk: The
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1710
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1710
# [DEBUG] Streamer received text chunk: Clerk
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1716
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1716
# [DEBUG] Streamer received text chunk: will
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1721
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1721
# [DEBUG] Streamer received text chunk: attest
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1728
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1728
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1732
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1732
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: affix
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1738
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1738
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1742
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1742
# [DEBUG] Streamer received text chunk: seal
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1747
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1747
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1750
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1750
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1754
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1754
# [DEBUG] Streamer received text chunk: City
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1759
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1759
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1763
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1763
# [DEBUG] Streamer received text chunk: County
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1770
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1770
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1773
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1773
# [DEBUG] Streamer received text chunk: Denver
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1780
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1780
# [DEBUG] Streamer received text chunk: to
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1783
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1783
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1787
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1787
# [DEBUG] Streamer received text chunk: proclamation
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1800
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1800
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1804
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1804
# [DEBUG] Streamer received text chunk: transmit
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1813
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1813
# [DEBUG] Streamer received text chunk: a
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1815
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1815
# [DEBUG] Streamer received text chunk: copy
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1820
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1820
# [DEBUG] Streamer received text chunk: to
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1823
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1823
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1827
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1827
# [DEBUG] Streamer received text chunk: Denver
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1834
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1834
# [DEBUG] Streamer received text chunk: American
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1843
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1843
# [DEBUG] Streamer received text chunk: Indian
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1850
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1850
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Commission,
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1862
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1862
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1866
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1866
# [DEBUG] Streamer received text chunk: City
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1871
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1871
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1875
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1875
# [DEBUG] Streamer received text chunk: County
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1882
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1882
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1885
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1885
# [DEBUG] Streamer received text chunk: Denver
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1892
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1892
# [DEBUG] Streamer received text chunk: School
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1899
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1899
# [DEBUG] Streamer received text chunk: District
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1908
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1908
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: No.
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1912
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1912
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: 1,
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1915
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1915
# [DEBUG] Streamer received text chunk: and
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1919
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1919
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1923
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1923
# [DEBUG] Streamer received text chunk: Colorado
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1932
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1932
# [DEBUG] Streamer received text chunk: Commission
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1943
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1943
# [DEBUG] Streamer received text chunk: on
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1946
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1946
# [DEBUG] Streamer received text chunk: Indian
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1953
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1953
# [DEBUG] Streamer received text chunk: Affairs.
#
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1963
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1963
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: **Owners:**
#
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1976
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1976
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: *
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1978
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1978
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: **Councilman
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 1991
# [DEBUG] GradioInterface yielding chunk to UI. Length: 1991
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Lopez:**
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2000
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2000
# [DEBUG] Streamer received text chunk: Sponsor
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2008
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2008
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2011
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2011
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2015
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2015
# [DEBUG] Streamer received text chunk: proclamation
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2028
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2028
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: *
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2030
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2030
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: **Councilwoman
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2045
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2045
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Ortega:**
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2055
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2055
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Co-sponsor
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2066
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2066
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2069
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2069
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2073
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2073
# [DEBUG] Streamer received text chunk: proclamation
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2086
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2086
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: *
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2088
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2088
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: **Councilwoman
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2103
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2103
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Kinneach:**
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2115
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2115
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: Co-sponsor
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2126
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2126
# [DEBUG] Streamer received text chunk: of
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2129
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2129
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2133
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2133
# [DEBUG] Streamer received text chunk: proclamation
#
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2146
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2146
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: *
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2148
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2148
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: **Clerk:**
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2159
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2159
# [DEBUG] Streamer received text chunk: Responsible
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2171
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2171
# [DEBUG] Streamer received text chunk: for
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2175
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2175
# [DEBUG] Streamer received text chunk: transmitting
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2188
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2188
# [DEBUG] Streamer received text chunk: the
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2192
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2192
# [DEBUG] Streamer received text chunk: proclamation
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2205
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2205
# [DEBUG] Streamer received text chunk: to
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2208
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2208
# [DEBUG] Streamer received text chunk: relevant
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2217
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2217
# [DEBUG] Streamer received text chunk:
# [DEBUG] Streamer received text chunk: parties<|eot_id|>
# [DEBUG] Yielding accumulated chunk to GradioInterface. Current length: 2224
# [DEBUG] GradioInterface yielding chunk to UI. Length: 2224
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://f7cc830a29bd4e5c68.gradio.live
